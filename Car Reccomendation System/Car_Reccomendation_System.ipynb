# %%
import numpy as np
import pylab as pl
import pandas as pd
import matplotlib.pyplot as plt 
# %matplotlib inline
import seaborn as sns
from sklearn.utils import shuffle
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.model_selection import cross_val_score, GridSearchCV
# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os

# %%
Data = pd.read_csv("/content/CAR DETAILS FROM CAR DEKHO.xls")
Data.info()
Data[0:10]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4340 entries, 0 to 4339
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           4340 non-null   object
#  1   year           4340 non-null   int64
#  2   selling_price  4340 non-null   int64
#  3   km_driven      4340 non-null   int64
#  4   fuel           4340 non-null   object
#  5   seller_type    4340 non-null   object
#  6   transmission   4340 non-null   object
#  7   owner          4340 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 271.4+ KB
#                         name  year  selling_price  km_driven    fuel  \
# 0              Maruti 800 AC  2007          60000      70000  Petrol
# 1   Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2       Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3     Datsun RediGO T Option  2017         250000      46000  Petrol
# 4      Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
# 5       Maruti Alto LX BSIII  2007         140000     125000  Petrol
# 6  Hyundai Xcent 1.2 Kappa S  2016         550000      25000  Petrol
# 7   Tata Indigo Grand Petrol  2014         240000      60000  Petrol
# 8   Hyundai Creta 1.6 VTVT S  2015         850000      25000  Petrol
# 9   Maruti Celerio Green VXI  2017         365000      78000     CNG
#
#   seller_type transmission         owner
# 0  Individual       Manual   First Owner
# 1  Individual       Manual   First Owner
# 2  Individual       Manual   First Owner
# 3  Individual       Manual   First Owner
# 4  Individual       Manual  Second Owner
# 5  Individual       Manual   First Owner
# 6  Individual       Manual   First Owner
# 7  Individual       Manual  Second Owner
# 8  Individual       Manual   First Owner
# 9  Individual       Manual   First Owner

# %% [markdown]
# NAME OF THE CARS

# %%
cnt_pro = Data['name'].value_counts()  [:50]
plt.figure(figsize=(7,4))
sns.barplot(cnt_pro.index, cnt_pro.values, alpha=0.8)
plt.ylabel('Number of Data', fontsize=12)
plt.xlabel('name', fontsize=9)
plt.xticks(rotation=90)
plt.show();
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# OWNER

# %%
cnt_pro = Data['owner'].value_counts()
plt.figure(figsize=(6,4))
sns.barplot(cnt_pro.index, cnt_pro.values, alpha=0.8)
plt.ylabel('Number of Data', fontsize=12)
plt.xlabel('owner', fontsize=12)
plt.xticks(rotation=80)
plt.show();
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Seller type

# %%
cnt_pro = Data['seller_type'].value_counts()
plt.figure(figsize=(6,4))
sns.barplot(cnt_pro.index, cnt_pro.values, alpha=0.8)
plt.ylabel('Number of seller_type', fontsize=12)
plt.xlabel('seller_type', fontsize=12)
plt.xticks(rotation=80)
plt.show();
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# The selling price of the Cars

# %%
top_sell = Data.sort_values(by='selling_price', ascending=False)
figure = plt.figure(figsize=(10,6))
sns.barplot(y=top_sell.seller_type, x=top_sell.selling_price)
plt.xticks()
plt.xlabel('selling_price')
plt.ylabel('seller_type')
plt.title('The selling price of car')
plt.show()

# %% [markdown]
# As you can see on the figure above, we know that car who sell by Dealer and Trustmark Dealer has higher selling price than sell by Individual
# THE SELLING PRICE OF CAR BY YEAR

# %%
top_sell = Data.sort_values(by='year', ascending=True)[:30]
figure = plt.figure(figsize=(10,6))
sns.barplot(y=top_sell.selling_price, x=top_sell.year)
plt.xticks()
plt.xlabel('year')
plt.ylabel('selling_price')
plt.title('The selling price of Car by year')
plt.show()

# %% [markdown]
# COMPARING THE SELLING PRICE OF THE CARS

# %%
# here we are comparing the selling_price with name (vehicle)
# first group the name and get max,min and avg selling price of the vehicle
display(Data[["name","selling_price",]].groupby(["name"]).agg(["max",'mean',"min"]).style.background_gradient(cmap="Blues"))
# here we are ploting these values using lineplot
Data[["name","selling_price",]].groupby(["name"]).agg(["max",'mean',"min"]).plot(kind="line",color =["red","black","blue"])
plt.title("Which car is most selling price?", fontsize=20)
#plt.xticks(np.arange(17),['Maruti Swift Dzire VDI','Maruti Alto 800 LXI','Maruti Alto LXi','Hyundai EON Era Plus','Maruti Alto LX'],rotation=90,fontsize=15)
plt.ylabel("selling_price",fontsize=9) 
plt.xticks(rotation=80)
#plt.xlabel(" ")
plt.show()
print("History's Best Selling Vehicles")
display(Data.loc[Data.groupby(Data["name"])["selling_price"].idxmax()][["name",
                                                                  "selling_price"]].style.background_gradient(cmap="copper"))
# Out:
# <style type="text/css">
# #T_dad0d_row0_col0, #T_dad0d_row0_col1, #T_dad0d_row0_col2, #T_dad0d_row48_col0, #T_dad0d_row48_col1, #T_dad0d_row48_col2, #T_dad0d_row49_col0, #T_dad0d_row49_col1, #T_dad0d_row49_col2, #T_dad0d_row51_col2, #T_dad0d_row52_col2, #T_dad0d_row55_col2, #T_dad0d_row56_col2, #T_dad0d_row70_col0, #T_dad0d_row70_col1, #T_dad0d_row70_col2, #T_dad0d_row84_col1, #T_dad0d_row89_col0, #T_dad0d_row89_col1, #T_dad0d_row89_col2, #T_dad0d_row141_col0, #T_dad0d_row141_col1, #T_dad0d_row141_col2, #T_dad0d_row193_col0, #T_dad0d_row193_col1, #T_dad0d_row193_col2, #T_dad0d_row197_col0, #T_dad0d_row197_col1, #T_dad0d_row197_col2, #T_dad0d_row198_col1, #T_dad0d_row198_col2, #T_dad0d_row201_col0, #T_dad0d_row201_col1, #T_dad0d_row201_col2, #T_dad0d_row204_col0, #T_dad0d_row206_col1, #T_dad0d_row206_col2, #T_dad0d_row233_col2, #T_dad0d_row237_col2, #T_dad0d_row249_col0, #T_dad0d_row249_col1, #T_dad0d_row249_col2, #T_dad0d_row255_col0, #T_dad0d_row255_col1, #T_dad0d_row255_col2, #T_dad0d_row297_col0, #T_dad0d_row297_col1, #T_dad0d_row297_col2, #T_dad0d_row300_col2, #T_dad0d_row301_col0, #T_dad0d_row301_col1, #T_dad0d_row301_col2, #T_dad0d_row365_col1, #T_dad0d_row366_col2, #T_dad0d_row368_col0, #T_dad0d_row368_col1, #T_dad0d_row368_col2, #T_dad0d_row371_col1, #T_dad0d_row371_col2, #T_dad0d_row372_col0, #T_dad0d_row372_col1, #T_dad0d_row372_col2, #T_dad0d_row373_col2, #T_dad0d_row391_col2, #T_dad0d_row421_col2, #T_dad0d_row422_col0, #T_dad0d_row422_col1, #T_dad0d_row422_col2, #T_dad0d_row423_col2, #T_dad0d_row425_col0, #T_dad0d_row425_col1, #T_dad0d_row425_col2, #T_dad0d_row428_col0, #T_dad0d_row428_col1, #T_dad0d_row462_col0, #T_dad0d_row466_col0, #T_dad0d_row473_col0, #T_dad0d_row473_col1, #T_dad0d_row473_col2, #T_dad0d_row474_col2, #T_dad0d_row481_col0, #T_dad0d_row483_col0, #T_dad0d_row483_col1, #T_dad0d_row483_col2, #T_dad0d_row486_col1, #T_dad0d_row536_col0, #T_dad0d_row536_col1, #T_dad0d_row536_col2, #T_dad0d_row552_col2, #T_dad0d_row555_col2, #T_dad0d_row630_col2, #T_dad0d_row649_col2, #T_dad0d_row670_col1, #T_dad0d_row672_col0, #T_dad0d_row672_col1, #T_dad0d_row672_col2, #T_dad0d_row681_col2, #T_dad0d_row775_col1, #T_dad0d_row777_col0, #T_dad0d_row778_col0, #T_dad0d_row783_col0, #T_dad0d_row787_col2, #T_dad0d_row788_col2, #T_dad0d_row793_col2, #T_dad0d_row801_col2, #T_dad0d_row811_col1, #T_dad0d_row812_col1, #T_dad0d_row813_col0, #T_dad0d_row814_col1, #T_dad0d_row815_col0, #T_dad0d_row815_col1, #T_dad0d_row815_col2, #T_dad0d_row816_col2, #T_dad0d_row817_col0, #T_dad0d_row818_col2, #T_dad0d_row829_col1, #T_dad0d_row895_col0, #T_dad0d_row897_col0, #T_dad0d_row897_col1, #T_dad0d_row897_col2, #T_dad0d_row898_col1, #T_dad0d_row901_col0, #T_dad0d_row901_col1, #T_dad0d_row901_col2, #T_dad0d_row918_col0, #T_dad0d_row918_col1, #T_dad0d_row922_col2, #T_dad0d_row928_col2, #T_dad0d_row942_col0, #T_dad0d_row942_col1, #T_dad0d_row942_col2, #T_dad0d_row953_col2, #T_dad0d_row988_col2, #T_dad0d_row989_col2, #T_dad0d_row1005_col2, #T_dad0d_row1029_col2, #T_dad0d_row1032_col1, #T_dad0d_row1032_col2, #T_dad0d_row1033_col2, #T_dad0d_row1035_col2, #T_dad0d_row1036_col1, #T_dad0d_row1036_col2, #T_dad0d_row1039_col1, #T_dad0d_row1045_col2, #T_dad0d_row1048_col2, #T_dad0d_row1059_col0, #T_dad0d_row1059_col1, #T_dad0d_row1060_col2, #T_dad0d_row1061_col0, #T_dad0d_row1061_col1, #T_dad0d_row1061_col2, #T_dad0d_row1063_col0, #T_dad0d_row1063_col1, #T_dad0d_row1063_col2, #T_dad0d_row1065_col2, #T_dad0d_row1066_col2, #T_dad0d_row1068_col1, #T_dad0d_row1070_col0, #T_dad0d_row1072_col0, #T_dad0d_row1076_col0, #T_dad0d_row1076_col1, #T_dad0d_row1076_col2, #T_dad0d_row1077_col0, #T_dad0d_row1077_col1, #T_dad0d_row1177_col0, #T_dad0d_row1177_col1, #T_dad0d_row1177_col2, #T_dad0d_row1178_col0, #T_dad0d_row1178_col1, #T_dad0d_row1178_col2, #T_dad0d_row1216_col0, #T_dad0d_row1222_col0, #T_dad0d_row1222_col1, #T_dad0d_row1222_col2, #T_dad0d_row1224_col0, #T_dad0d_row1224_col1, #T_dad0d_row1224_col2, #T_dad0d_row1225_col1, #T_dad0d_row1228_col1, #T_dad0d_row1228_col2, #T_dad0d_row1229_ ...
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_dad0d_row1_col0, #T_dad0d_row1_col1, #T_dad0d_row1_col2, #T_dad0d_row85_col2, #T_dad0d_row250_col2, #T_dad0d_row253_col0, #T_dad0d_row253_col1, #T_dad0d_row253_col2, #T_dad0d_row254_col0, #T_dad0d_row254_col1, #T_dad0d_row254_col2, #T_dad0d_row460_col2, #T_dad0d_row464_col2, #T_dad0d_row465_col2, #T_dad0d_row775_col2, #T_dad0d_row776_col1, #T_dad0d_row776_col2, #T_dad0d_row780_col2, #T_dad0d_row781_col0, #T_dad0d_row781_col1, #T_dad0d_row781_col2, #T_dad0d_row782_col2, #T_dad0d_row811_col2, #T_dad0d_row894_col2, #T_dad0d_row913_col0, #T_dad0d_row913_col1, #T_dad0d_row913_col2, #T_dad0d_row917_col0, #T_dad0d_row917_col1, #T_dad0d_row917_col2, #T_dad0d_row1044_col0, #T_dad0d_row1044_col1, #T_dad0d_row1044_col2, #T_dad0d_row1070_col2, #T_dad0d_row1128_col0, #T_dad0d_row1128_col1, #T_dad0d_row1128_col2, #T_dad0d_row1216_col2, #T_dad0d_row1217_col2, #T_dad0d_row1218_col0, #T_dad0d_row1218_col1, #T_dad0d_row1218_col2, #T_dad0d_row1220_col2, #T_dad0d_row1277_col1, #T_dad0d_row1277_col2, #T_dad0d_row1280_col2, #T_dad0d_row1281_col2, #T_dad0d_row1283_col2, #T_dad0d_row1285_col0, #T_dad0d_row1285_col1, #T_dad0d_row1285_col2, #T_dad0d_row1286_col0, #T_dad0d_row1286_col1, #T_dad0d_row1286_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_dad0d_row2_col0, #T_dad0d_row2_col1, #T_dad0d_row2_col2, #T_dad0d_row65_col0, #T_dad0d_row68_col1, #T_dad0d_row97_col0, #T_dad0d_row97_col1, #T_dad0d_row97_col2, #T_dad0d_row103_col0, #T_dad0d_row103_col1, #T_dad0d_row103_col2, #T_dad0d_row109_col0, #T_dad0d_row109_col1, #T_dad0d_row109_col2, #T_dad0d_row136_col1, #T_dad0d_row145_col0, #T_dad0d_row145_col1, #T_dad0d_row145_col2, #T_dad0d_row147_col2, #T_dad0d_row170_col2, #T_dad0d_row171_col2, #T_dad0d_row184_col1, #T_dad0d_row205_col0, #T_dad0d_row210_col0, #T_dad0d_row210_col1, #T_dad0d_row210_col2, #T_dad0d_row211_col1, #T_dad0d_row221_col2, #T_dad0d_row225_col0, #T_dad0d_row225_col1, #T_dad0d_row225_col2, #T_dad0d_row226_col2, #T_dad0d_row231_col0, #T_dad0d_row233_col0, #T_dad0d_row241_col0, #T_dad0d_row241_col1, #T_dad0d_row256_col0, #T_dad0d_row256_col1, #T_dad0d_row256_col2, #T_dad0d_row257_col0, #T_dad0d_row261_col0, #T_dad0d_row263_col0, #T_dad0d_row264_col0, #T_dad0d_row264_col1, #T_dad0d_row271_col2, #T_dad0d_row275_col0, #T_dad0d_row275_col1, #T_dad0d_row275_col2, #T_dad0d_row294_col0, #T_dad0d_row303_col0, #T_dad0d_row307_col1, #T_dad0d_row311_col0, #T_dad0d_row312_col0, #T_dad0d_row312_col1, #T_dad0d_row312_col2, #T_dad0d_row322_col2, #T_dad0d_row348_col0, #T_dad0d_row348_col1, #T_dad0d_row348_col2, #T_dad0d_row350_col2, #T_dad0d_row355_col1, #T_dad0d_row358_col2, #T_dad0d_row360_col1, #T_dad0d_row429_col2, #T_dad0d_row430_col0, #T_dad0d_row433_col0, #T_dad0d_row433_col1, #T_dad0d_row433_col2, #T_dad0d_row434_col2, #T_dad0d_row438_col1, #T_dad0d_row439_col1, #T_dad0d_row440_col0, #T_dad0d_row440_col1, #T_dad0d_row445_col0, #T_dad0d_row445_col1, #T_dad0d_row445_col2, #T_dad0d_row446_col1, #T_dad0d_row447_
# History's Best Selling Vehicles
# <style type="text/css">
# #T_ab557_row0_col1, #T_ab557_row48_col1, #T_ab557_row49_col1, #T_ab557_row70_col1, #T_ab557_row89_col1, #T_ab557_row141_col1, #T_ab557_row193_col1, #T_ab557_row197_col1, #T_ab557_row201_col1, #T_ab557_row204_col1, #T_ab557_row249_col1, #T_ab557_row255_col1, #T_ab557_row297_col1, #T_ab557_row301_col1, #T_ab557_row368_col1, #T_ab557_row372_col1, #T_ab557_row422_col1, #T_ab557_row425_col1, #T_ab557_row428_col1, #T_ab557_row462_col1, #T_ab557_row466_col1, #T_ab557_row473_col1, #T_ab557_row481_col1, #T_ab557_row483_col1, #T_ab557_row536_col1, #T_ab557_row672_col1, #T_ab557_row777_col1, #T_ab557_row778_col1, #T_ab557_row783_col1, #T_ab557_row813_col1, #T_ab557_row815_col1, #T_ab557_row817_col1, #T_ab557_row895_col1, #T_ab557_row897_col1, #T_ab557_row901_col1, #T_ab557_row918_col1, #T_ab557_row942_col1, #T_ab557_row1059_col1, #T_ab557_row1061_col1, #T_ab557_row1063_col1, #T_ab557_row1070_col1, #T_ab557_row1072_col1, #T_ab557_row1076_col1, #T_ab557_row1077_col1, #T_ab557_row1177_col1, #T_ab557_row1178_col1, #T_ab557_row1216_col1, #T_ab557_row1222_col1, #T_ab557_row1224_col1, #T_ab557_row1230_col1, #T_ab557_row1246_col1, #T_ab557_row1252_col1, #T_ab557_row1276_col1, #T_ab557_row1280_col1, #T_ab557_row1281_col1, #T_ab557_row1283_col1, #T_ab557_row1311_col1, #T_ab557_row1315_col1, #T_ab557_row1316_col1, #T_ab557_row1336_col1, #T_ab557_row1364_col1 {
#   background-color: #020201;
#   color: #f1f1f1;
# }
# #T_ab557_row1_col1, #T_ab557_row253_col1, #T_ab557_row254_col1, #T_ab557_row781_col1, #T_ab557_row913_col1, #T_ab557_row917_col1, #T_ab557_row1044_col1, #T_ab557_row1128_col1, #T_ab557_row1218_col1, #T_ab557_row1285_col1, #T_ab557_row1286_col1 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_ab557_row2_col1, #T_ab557_row65_col1, #T_ab557_row109_col1, #T_ab557_row231_col1, #T_ab557_row233_col1, #T_ab557_row256_col1, #T_ab557_row261_col1, #T_ab557_row263_col1, #T_ab557_row294_col1, #T_ab557_row303_col1, #T_ab557_row312_col1, #T_ab557_row430_col1, #T_ab557_row433_col1, #T_ab557_row453_col1, #T_ab557_row539_col1, #T_ab557_row601_col1, #T_ab557_row602_col1, #T_ab557_row604_col1, #T_ab557_row643_col1, #T_ab557_row652_col1, #T_ab557_row657_col1, #T_ab557_row661_col1, #T_ab557_row679_col1, #T_ab557_row703_col1, #T_ab557_row837_col1, #T_ab557_row840_col1, #T_ab557_row846_col1, #T_ab557_row870_col1, #T_ab557_row902_col1, #T_ab557_row964_col1, #T_ab557_row965_col1, #T_ab557_row987_col1, #T_ab557_row1024_col1, #T_ab557_row1046_col1, #T_ab557_row1105_col1, #T_ab557_row1112_col1, #T_ab557_row1193_col1, #T_ab557_row1209_col1, #T_ab557_row1323_col1, #T_ab557_row1324_col1, #T_ab557_row1325_col1, #T_ab557_row1358_col1, #T_ab557_row1368_col1, #T_ab557_row1372_col1, #T_ab557_row1375_col1, #T_ab557_row1381_col1, #T_ab557_row1454_col1, #T_ab557_row1457_col1, #T_ab557_row1460_col1 {
#   background-color: #0e0905;
#   color: #f1f1f1;
# }
# #T_ab557_row3_col1, #T_ab557_row31_col1, #T_ab557_row333_col1, #T_ab557_row336_col1, #T_ab557_row385_col1, #T_ab557_row388_col1, #T_ab557_row502_col1, #T_ab557_row695_col1, #T_ab557_row742_col1, #T_ab557_row745_col1, #T_ab557_row1179_col1, #T_ab557_row1212_col1, #T_ab557_row1415_col1 {
#   background-color: #2a1b11;
#   color: #f1f1f1;
# }
# #T_ab557_row4_col1, #T_ab557_row521_col1, #T_ab557_row616_col1, #T_ab557_row665_col1, #T_ab557_row741_col1, #T_ab557_row751_col1, #T_ab557_row1211_col1, #T_ab557_row1398_col1, #T_ab557_row1422_col1 {
#   background-color: #2c1c12;
#   color: #f1f1f1;
# }
# #T_ab557_row5_col1, #T_ab557_row335_col1, #T_ab557_row387_col1, #T_ab557_row736_col1, #T_ab557_row738_col1, #T_ab557_row752_col1, #T_ab557_row1361_col1, #T_ab557_row1413_col1 {
#   background-color: #281910;
#   color: #f1f1f1;
# }
# #T_ab557_row6_col1, #T_ab557_row10_col1, #T_ab557_row28_col1, #T_ab557_row405_col1 {
#   background-color: #362216;
#   color: #f1f1f1;
# }
# #T_ab557_row7_col1, #T_ab557_row1387_col1 {
#   background-color: #6d452c;
#   color: #f1f1f1;
# }
# #T_ab557_row8_col1, #T_ab557_row26_col1 {
#   background-color: #503320;
#   color: #f1f1f1;
# }
# #T_ab557_row9_col1 {
#   background-color: #73492e;
#   color: #f1f1f1;
# }
# #T_ab557_row11_col1 {
#   background-color: #a66943;
#   color: #f1f1f1;
# }
# #T_ab557_row12_col1, #T_ab557_row18_col1, #T_ab557_row1423_col1, #T_ab557_row1489_col1 {
#   background-color: #3d2618;
#   color: #f1f1f1;
# }
# #T_ab557_row13_col1, #T_ab557_row389_col1, #T_ab557_row1087_col1 {
#   background-color: #332014;
#   color: #f1f1f1;
# }
# #T_ab557_row14_col1, #T_ab557_row147_col1, #T_ab557_row156_col1, #T_ab557_row245_col1, #T_ab557_row247_col1, #T_ab557_row274_col1, #T_ab557_row310_col1, #T_ab557_row315_col1, #T_ab557_row345_col1, #T_ab557_row383_col1, #T_ab557_row384_col1, #T_ab557_row412_col1, #T_ab557_row574_col1, #T_ab557_row586_col1, #T_ab557_row634_col1, #T_ab557_row693_col1, #T_ab557_row714_col1, #T_ab557_row773_col1, #T_ab557_row821_col1, #T_ab557_row822_col1, #T_ab557_row853_col1, #T_ab557_row1084_col1, #T_ab557_row1100_col1, #T_ab557_row1123_col1, #T_ab557_row1130_col1, #T_ab557_row1194_col1, #T_ab557_row1203_col1, #T_ab557_row1355_col1, #T_ab557_row1416_col1, #T_ab557_row1433_col1, #T_ab557_row1447_col1, #T_ab557_row1463_col1 {
#   background-color: #1c120b;
#   color: #f1f1f1;
# }
# #T_ab557_row15_col1, #T_ab557_row122_col1, #T_ab557_row165_col1, #T_ab557_row166_col1, #T_ab557_row175_col1, #T_ab557_row221_col1, #T_ab557_row226_col1, #T_ab557_row248_col1, #T_ab557_row328_col1, #T_ab557_row354_col1, #T_ab557_row357_col1, #T_ab557_row407_col1, #T_ab557_row408_col1, #T_ab557_row413_col1, #T_ab557_row434_col1, #T_ab557_row505_col1, #T_ab557_row506_col1, #T_ab557_row507_col1, #T_ab557_row548_col1, #T_ab557_row573_col1, #T_ab557_row584_col1, #T_ab557_row588_col1, #T_ab557_row704_col1, #T_ab557_row824_col1, #T_ab557_row851_col1, #T_ab557_row858_col1, #T_ab557_row939_col1, #T_ab557_row963_col1, #T_ab557_row980_col1, #T_ab557_row1009_col1, #T_ab557_row1012_col1, #T_ab557_row1102_col1, #T_ab557_row1120_col1, #T_ab557_row1159_col1, #T_ab557_row1197_col1, #T_ab557_row1199_col1, #T_ab557_row1201_col1, #T_ab557_row1335_col1, #T_ab557_row1349_col1, #T_ab557_row1374_col1, #T_ab557_row1382_col1, #T_ab557_row1395_col1, #T_ab557_row1438_col1, #T_ab557_row1458_col1, #T_ab557_row1477_col1 {
#   background-color: #160e09;
#   color: #f1f1f1;
# }
# #T_ab557_row16_col1, #T_ab557_row182_col1 {
#   background-color: #633e28;
#   color: #f1f1f1;
# }
# #T_ab557_row17_col1, #T_ab557_row24_col1, #T_ab557_row174_col1, #T_ab557_row281_col1, #T_ab557_row283_col1, #T_ab557_row284_col1, #T_ab557_row363_col1, #T_ab557_row380_col1, #T_ab557_row382_col1, #T_ab557_row743_col1, #T_ab557_row1307_col1 {
#   background-color: #2b1b11;
#   color: #f1f1f1;
# }
# #T_ab557_row19_col1, #T_ab557_row624_col1 {
#   background-color: #5f3c26;
#   color: #f1f1f1;
# }
# #T_ab557_row20_col1, #T_ab557_row618_col1 {
#   background-color: #7c4e32;
#   color: #f1f1f1;
# }
# #T_ab557_row21_col1, #T_ab557_row163_col1, #T_ab557_row176_col1, #T_ab557_row180_col1, #T_ab557_row517_col1, #T_ab557_row518_col1, #T_ab557_row533_col1, #T_ab557_row697_col1, #T_ab557_row774_col1, #T_ab557_row890_col1, #T_ab557_row1078_col1, #T_ab557_row1103_col1, #T_ab557_row1475_col1 {
#   background-color: #26180f;
#   color: #f1f1f1;
# }
# #T_ab557_row22_col1, #T_ab557_row622_col1, #T_ab557_row747_col1 {
#   background-color: #40291a;
#   color: #f1f1f1;
# }
# #T_ab557_row23_col1 {
#   background-color: #895737;
#   color: #f1f1f1;
# }
# #T_ab557_row25_col1 {
#   background-color: #ffc77f;
#   color: #000000;
# }
# #T_ab557_row27_col1, #T_ab557_row611_col1, #T_ab557_row1095_col1, #T_ab557_row1490_col1 {
#   background-color: #462d1c;
#   color: #f1f1f1;
# }
# #T_ab557_row29_col1 {
#   background-color: #6b442b;
#   color: #f1f1f1;
# }
# #T_ab557_row30_col1 {
#   background-color: #a96b44;
#   color: #f1f1f1;
# }
# #T_ab557_row32_col1, #T_ab557_row61_col1, #T_ab557_row68_col1, #T_ab557_row95_col1, #T_ab557_row137_col1, #T_ab557_row144_col1, #T_ab557_row168_col1, #T_ab557_row169_col1, #T_ab557_row179_col1, #T_ab557_row183_col1, #T_ab557_row218_col1, #T_ab557_row268_col1, #T_ab557_row269_col1, #T_ab557_row270_col1, #T_ab557_row271_col1, #T_ab557_row28

# %% [markdown]
# Time series selling price CARS

# %%
Data['year'] = Data["year"].astype("int")
print('time series selling price cars')
display(Data[["year",'name','selling_price']].groupby(["name",
                                                         "year"]).agg("sum").sort_values(by="selling_price",
                                                          ascending = False).head(10).style.background_gradient(cmap='Greens'))
# here we are plotting them
sns.lineplot(Data["year"],Data['selling_price'],hue=Data["seller_type"])
plt.title("time series selling cars by seller_type",fontsize=20)
plt.xticks(fontsize=18)
plt.xlabel(" ")
plt.show()
# Out:
# time series selling price cars
# <style type="text/css">
# #T_03b39_row0_col0 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_03b39_row1_col0 {
#   background-color: #2a924a;
#   color: #f1f1f1;
# }
# #T_03b39_row2_col0 {
#   background-color: #78c679;
#   color: #000000;
# }
# #T_03b39_row3_col0 {
#   background-color: #ceecc8;
#   color: #000000;
# }
# #T_03b39_row4_col0 {
#   background-color: #e7f6e2;
#   color: #000000;
# }
# #T_03b39_row5_col0 {
#   background-color: #f1faee;
#   color: #000000;
# }
# #T_03b39_row6_col0 {
#   background-color: #f4fbf1;
#   color: #000000;
# }
# #T_03b39_row7_col0, #T_03b39_row8_col0, #T_03b39_row9_col0 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_03b39_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >selling_price</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >name</th>
#       <th class="index_name level1" >year</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_03b39_level0_row0" class="row_heading level0 row0" >BMW X5 xDrive 30d xLine</th>
#       <th id="T_03b39_level1_row0" class="row_heading level1 row0" >2019</th>
#       <td id="T_03b39_row0_col0" class="data row0 col0" >54450000</td>
#     </tr>
#     <tr>
#       <th id="T_03b39_level0_row1" class="row_heading level0 row1" >Mercedes-Benz C-Class Progressive C 220d</th>
#       <th id="T_03b39_level1_row1" class="row_heading level1 row1" >2018</th>
#       <td id="T_03b39_row1_col0" class="data row1 col0" >41800000</td>
#     </tr>
#     <tr>
#       <th id="T_03b39_level0_row2" class="row_heading level0 row2" >Toyota Fortuner 4x2 AT</th>
#       <th id="T_03b39_level1_row2" class="row_heading level1 row2" >2017</th>
#       <td id="T_03b39_row2_col0" class="data row2 col0" >31195000</td>
#     </tr>
#     <tr>
#       <th id="T_03b39_level0_row3" class="row_heading level0 row3" >Audi A4 3.0 TDI Quattro</th>
#       <th id="T_03b39_level1_row3" class="row_heading level1 row3" >2013</th>
#       <td id="T_03b39_row3_col0" class="data row3 col0" >18960000</td>
#     </tr>
#     <tr>
#       <th id="T_03b39_level0_row4" class="row_heading level0 row4" >Audi A6 2.0 TDI Premium Plus</th>
#       <th id="T_03b39_level1_row4" class="row_heading level1 row4" >2013</th>
#       <td id="T_03b39_row4_col0" class="data row4 col0" >14300000</td>
#     </tr>
#     <tr>
#       <th id="T_03b39_level0_row5" class="row_heading level0 row5" >Maruti Swift Dzire VDI</th>
#       <th id="T_03b39_level1_row5" class="row_heading level1 row5" >2017</th>
#       <td id="T_03b39_row5_col0" class="data row5 col0" >10893000</td>
#     </tr>
#     <tr>
#       <th id="T_03b39_level0_row6" class="row_heading level0 row6" >Hyundai Creta 1.6 CRDi SX</th>
#       <th id="T_03b39_level1_row6" class="row_heading level1 row6" >2016</th>
#       <td id="T_03b39_row6_col0" class="data row6 col0" >10178999</td>
#     </tr>
#     <tr>
#       <th id="T_03b39_level0_row7" class="row_heading level0 row7" >Hyundai Verna 1.6 VTVT SX</th>
#       <th id="T_03b39_level1_row7" class="row_heading level1 row7" >2015</th>
#       <td id="T_03b39_row7_col0" class="data row7 col0" >9120000</td>
#     </tr>
#     <tr>
#       <th id="T_03b39_level0_row8" class="row_heading level0 row8" >Maruti S-Cross Zeta DDiS 200 SH</th>
#       <th id="T_03b39_level1_row8" class="row_heading level1 row8" >2015</th>
#       <td id="T_03b39_row8_col0" class="data row8 col0" >9000000</td>
#     </tr>
#     <tr>
#       <th id="T_03b39_level0_row9" class="row_heading level0 row9" >Mercedes-Benz E-Class Exclusive E 200 BSIV</th>
#       <th id="T_03b39_level1_row9" class="row_heading level1 row9" >2018</th>
#       <td id="T_03b39_row9_col0" class="data row9 col0" >9000000</td>
#     </tr>
#   </tbody>
# </table>
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# 7 things you need to know before buying a car
#
# Besides paying attention to financial, if you want buy car you need to know about the car like:
#
#     type of car,
#     year,
#     transmission,
#     km_driven,
#     fuel
#     seller type ,
#     selling price
#
# As I mentioned before, when we buy vehicle from Dealer and Trustmark Dealer it has higher selling price than sell by Individual.

# %%
display(Data[Data["owner"]=="First Owner"][["name","transmission","year","km_driven","fuel","seller_type",
                                       "selling_price"]].sort_values(by="selling_price", ascending= False).head(5).style.background_gradient(cmap="spring"))
display(Data[Data["owner"]=="Second Owner"][["name","transmission","year","km_driven","fuel","seller_type",
                                       "selling_price"]].sort_values(by="selling_price", ascending= False).head(5).style.background_gradient(cmap="spring"))

display(Data[Data["owner"]=="Third Owner"][["name","transmission","year","km_driven","fuel","seller_type",
                                       "selling_price"]].sort_values(by="selling_price", ascending= False).head(5).style.background_gradient(cmap="spring"))

display(Data[Data["owner"]=="Fourth & Above Owner"][["name","transmission","year","km_driven","fuel","seller_type",
                                       "selling_price"]].sort_values(by="selling_price", ascending= False).head(5).style.background_gradient(cmap="spring"))

display(Data[Data["owner"]=="Test Drive Car"][["name","transmission","year","km_driven","fuel","seller_type",
                                       "selling_price"]].sort_values(by="selling_price", ascending= False).head(5).style.background_gradient(cmap="spring"))


sns.barplot(Data["owner"],Data["km_driven"],hue= Data["seller_type"],palette="spring")
plt.xticks(rotation=80)
plt.title("seller_type : km_driven comparsion")
# Out:
# <style type="text/css">
# #T_ce3ff_row0_col2, #T_ce3ff_row1_col3, #T_ce3ff_row2_col2, #T_ce3ff_row3_col6, #T_ce3ff_row4_col6 {
#   background-color: #ff00ff;
#   color: #f1f1f1;
# }
# #T_ce3ff_row0_col3 {
#   background-color: #ff17e8;
#   color: #f1f1f1;
# }
# #T_ce3ff_row0_col6, #T_ce3ff_row2_col3, #T_ce3ff_row3_col2, #T_ce3ff_row4_col2 {
#   background-color: #ffff00;
#   color: #000000;
# }
# #T_ce3ff_row1_col2 {
#   background-color: #ff55aa;
#   color: #f1f1f1;
# }
# #T_ce3ff_row1_col6 {
#   background-color: #ffcf30;
#   color: #000000;
# }
# #T_ce3ff_row2_col6 {
#   background-color: #ff23dc;
#   color: #f1f1f1;
# }
# #T_ce3ff_row3_col3, #T_ce3ff_row4_col3 {
#   background-color: #ff54ab;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ce3ff_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >transmission</th>
#       <th class="col_heading level0 col2" >year</th>
#       <th class="col_heading level0 col3" >km_driven</th>
#       <th class="col_heading level0 col4" >fuel</th>
#       <th class="col_heading level0 col5" >seller_type</th>
#       <th class="col_heading level0 col6" >selling_price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ce3ff_level0_row0" class="row_heading level0 row0" >3872</th>
#       <td id="T_ce3ff_row0_col0" class="data row0 col0" >Audi RS7 2015-2019 Sportback Performance</td>
#       <td id="T_ce3ff_row0_col1" class="data row0 col1" >Automatic</td>
#       <td id="T_ce3ff_row0_col2" class="data row0 col2" >2016</td>
#       <td id="T_ce3ff_row0_col3" class="data row0 col3" >13000</td>
#       <td id="T_ce3ff_row0_col4" class="data row0 col4" >Petrol</td>
#       <td id="T_ce3ff_row0_col5" class="data row0 col5" >Dealer</td>
#       <td id="T_ce3ff_row0_col6" class="data row0 col6" >8900000</td>
#     </tr>
#     <tr>
#       <th id="T_ce3ff_level0_row1" class="row_heading level0 row1" >89</th>
#       <td id="T_ce3ff_row1_col0" class="data row1 col0" >Mercedes-Benz S-Class S 350d Connoisseurs Edition</td>
#       <td id="T_ce3ff_row1_col1" class="data row1 col1" >Automatic</td>
#       <td id="T_ce3ff_row1_col2" class="data row1 col2" >2017</td>
#       <td id="T_ce3ff_row1_col3" class="data row1 col3" >6500</td>
#       <td id="T_ce3ff_row1_col4" class="data row1 col4" >Diesel</td>
#       <td id="T_ce3ff_row1_col5" class="data row1 col5" >Dealer</td>
#       <td id="T_ce3ff_row1_col6" class="data row1 col6" >8150000</td>
#     </tr>
#     <tr>
#       <th id="T_ce3ff_level0_row2" class="row_heading level0 row2" >3969</th>
#       <td id="T_ce3ff_row2_col0" class="data row2 col0" >Mercedes-Benz GLS 2016-2020 350d 4MATIC</td>
#       <td id="T_ce3ff_row2_col1" class="data row2 col1" >Automatic</td>
#       <td id="T_ce3ff_row2_col2" class="data row2 col2" >2016</td>
#       <td id="T_ce3ff_row2_col3" class="data row2 col3" >77350</td>
#       <td id="T_ce3ff_row2_col4" class="data row2 col4" >Diesel</td>
#       <td id="T_ce3ff_row2_col5" class="data row2 col5" >Dealer</td>
#       <td id="T_ce3ff_row2_col6" class="data row2 col6" >5500000</td>
#     </tr>
#     <tr>
#       <th id="T_ce3ff_level0_row3" class="row_heading level0 row3" >919</th>
#       <td id="T_ce3ff_row3_col0" class="data row3 col0" >BMW X5 xDrive 30d xLine</td>
#       <td id="T_ce3ff_row3_col1" class="data row3 col1" >Automatic</td>
#       <td id="T_ce3ff_row3_col2" class="data row3 col2" >2019</td>
#       <td id="T_ce3ff_row3_col3" class="data row3 col3" >30000</td>
#       <td id="T_ce3ff_row3_col4" class="data row3 col4" >Diesel</td>
#       <td id="T_ce3ff_row3_col5" class="data row3 col5" >Dealer</td>
#       <td id="T_ce3ff_row3_col6" class="data row3 col6" >4950000</td>
#     </tr>
#     <tr>
#       <th id="T_ce3ff_level0_row4" class="row_heading level0 row4" >593</th>
#       <td id="T_ce3ff_row4_col0" class="data row4 col0" >BMW X5 xDrive 30d xLine</td>
#       <td id="T_ce3ff_row4_col1" class="data row4 col1" >Automatic</td>
#       <td id="T_ce3ff_row4_col2" class="data row4 col2" >2019</td>
#       <td id="T_ce3ff_row4_col3" class="data row4 col3" >30000</td>
#       <td id="T_ce3ff_row4_col4" class="data row4 col4" >Diesel</td>
#       <td id="T_ce3ff_row4_col5" class="data row4 col5" >Dealer</td>
#       <td id="T_ce3ff_row4_col6" class="data row4 col6" >4950000</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_d8e18_row0_col2, #T_d8e18_row1_col2, #T_d8e18_row4_col2 {
#   background-color: #ffaa55;
#   color: #000000;
# }
# #T_d8e18_row0_col3, #T_d8e18_row0_col6, #T_d8e18_row1_col3, #T_d8e18_row1_col6, #T_d8e18_row3_col2 {
#   background-color: #ffff00;
#   color: #000000;
# }
# #T_d8e18_row2_col2, #T_d8e18_row2_col3, #T_d8e18_row3_col6, #T_d8e18_row4_col6 {
#   background-color: #ff00ff;
#   color: #f1f1f1;
# }
# #T_d8e18_row2_col6 {
#   background-color: #ff06f9;
#   color: #f1f1f1;
# }
# #T_d8e18_row3_col3 {
#   background-color: #ff807f;
#   color: #f1f1f1;
# }
# #T_d8e18_row4_col3 {
#   background-color: #ffa857;
#   color: #000000;
# }
# </style>
# <table id="T_d8e18_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >transmission</th>
#       <th class="col_heading level0 col2" >year</th>
#       <th class="col_heading level0 col3" >km_driven</th>
#       <th class="col_heading level0 col4" >fuel</th>
#       <th class="col_heading level0 col5" >seller_type</th>
#       <th class="col_heading level0 col6" >selling_price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d8e18_level0_row0" class="row_heading level0 row0" >539</th>
#       <td id="T_d8e18_row0_col0" class="data row0 col0" >Mercedes-Benz GL-Class 350 CDI Blue Efficiency</td>
#       <td id="T_d8e18_row0_col1" class="data row0 col1" >Automatic</td>
#       <td id="T_d8e18_row0_col2" class="data row0 col2" >2014</td>
#       <td id="T_d8e18_row0_col3" class="data row0 col3" >100000</td>
#       <td id="T_d8e18_row0_col4" class="data row0 col4" >Diesel</td>
#       <td id="T_d8e18_row0_col5" class="data row0 col5" >Individual</td>
#       <td id="T_d8e18_row0_col6" class="data row0 col6" >4400000</td>
#     </tr>
#     <tr>
#       <th id="T_d8e18_level0_row1" class="row_heading level0 row1" >2178</th>
#       <td id="T_d8e18_row1_col0" class="data row1 col0" >Mercedes-Benz GL-Class 350 CDI Blue Efficiency</td>
#       <td id="T_d8e18_row1_col1" class="data row1 col1" >Automatic</td>
#       <td id="T_d8e18_row1_col2" class="data row1 col2" >2014</td>
#       <td id="T_d8e18_row1_col3" class="data row1 col3" >100000</td>
#       <td id="T_d8e18_row1_col4" class="data row1 col4" >Diesel</td>
#       <td id="T_d8e18_row1_col5" class="data row1 col5" >Individual</td>
#       <td id="T_d8e18_row1_col6" class="data row1 col6" >4400000</td>
#     </tr>
#     <tr>
#       <th id="T_d8e18_level0_row2" class="row_heading level0 row2" >163</th>
#       <td id="T_d8e18_row2_col0" class="data row2 col0" >Jaguar XJ 5.0 L V8 Supercharged</td>
#       <td id="T_d8e18_row2_col1" class="data row2 col1" >Automatic</td>
#       <td id="T_d8e18_row2_col2" class="data row2 col2" >2010</td>
#       <td id="T_d8e18_row2_col3" class="data row2 col3" >40000</td>
#       <td id="T_d8e18_row2_col4" class="data row2 col4" >Petrol</td>
#       <td id="T_d8e18_row2_col5" class="data row2 col5" >Individual</td>
#       <td id="T_d8e18_row2_col6" class="data row2 col6" >2550000</td>
#     </tr>
#     <tr>
#       <th id="T_d8e18_level0_row3" class="row_heading level0 row3" >4224</th>
#       <td id="T_d8e18_row3_col0" class="data row3 col0" >Toyota Fortuner 2.7 2WD AT</td>
#       <td id="T_d8e18_row3_col1" class="data row3 col1" >Automatic</td>
#       <td id="T_d8e18_row3_col2" class="data row3 col2" >2016</td>
#       <td id="T_d8e18_row3_col3" class="data row3 col3" >70000</td>
#       <td id="T_d8e18_row3_col4" class="data row3 col4" >Petrol</td>
#       <td id="T_d8e18_row3_col5" class="data row3 col5" >Individual</td>
#       <td id="T_d8e18_row3_col6" class="data row3 col6" >2500000</td>
#     </tr>
#     <tr>
#       <th id="T_d8e18_level0_row4" class="row_heading level0 row4" >836</th>
#       <td id="T_d8e18_row4_col0" class="data row4 col0" >Mercedes-Benz M-Class ML 350 CDI</td>
#       <td id="T_d8e18_row4_col1" class="data row4 col1" >Automatic</td>
#       <td id="T_d8e18_row4_col2" class="data row4 col2" >2014</td>
#       <td id="T_d8e18_row4_col3" class="data row4 col3" >79500</td>
#       <td id="T_d8e18_row4_col4" class="data row4 col4" >Diesel</td>
#       <td id="T_d8e18_row4_col5" class="data row4 col5" >Individual</td>
#       <td id="T_d8e18_row4_col6" class="data row4 col6" >2500000</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_37e93_row0_col2 {
#   background-color: #ffdb24;
#   color: #000000;
# }
# #T_37e93_row0_col3, #T_37e93_row2_col2, #T_37e93_row4_col6 {
#   background-color: #ff00ff;
#   color: #f1f1f1;
# }
# #T_37e93_row0_col6, #T_37e93_row3_col2, #T_37e93_row4_col3 {
#   background-color: #ffff00;
#   color: #000000;
# }
# #T_37e93_row1_col2 {
#   background-color: #ff6d92;
#   color: #f1f1f1;
# }
# #T_37e93_row1_col3 {
#   background-color: #ffcf30;
#   color: #000000;
# }
# #T_37e93_row1_col6 {
#   background-color: #ff807f;
#   color: #f1f1f1;
# }
# #T_37e93_row2_col3 {
#   background-color: #ff6e91;
#   color: #f1f1f1;
# }
# #T_37e93_row2_col6, #T_37e93_row3_col6 {
#   background-color: #ff0bf4;
#   color: #f1f1f1;
# }
# #T_37e93_row3_col3 {
#   background-color: #ff40bf;
#   color: #f1f1f1;
# }
# #T_37e93_row4_col2 {
#   background-color: #ffb649;
#   color: #000000;
# }
# </style>
# <table id="T_37e93_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >transmission</th>
#       <th class="col_heading level0 col2" >year</th>
#       <th class="col_heading level0 col3" >km_driven</th>
#       <th class="col_heading level0 col4" >fuel</th>
#       <th class="col_heading level0 col5" >seller_type</th>
#       <th class="col_heading level0 col6" >selling_price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_37e93_level0_row0" class="row_heading level0 row0" >1410</th>
#       <td id="T_37e93_row0_col0" class="data row0 col0" >Audi A4 35 TDI Premium</td>
#       <td id="T_37e93_row0_col1" class="data row0 col1" >Automatic</td>
#       <td id="T_37e93_row0_col2" class="data row0 col2" >2015</td>
#       <td id="T_37e93_row0_col3" class="data row0 col3" >35000</td>
#       <td id="T_37e93_row0_col4" class="data row0 col4" >Diesel</td>
#       <td id="T_37e93_row0_col5" class="data row0 col5" >Individual</td>
#       <td id="T_37e93_row0_col6" class="data row0 col6" >2300000</td>
#     </tr>
#     <tr>
#       <th id="T_37e93_level0_row1" class="row_heading level0 row1" >3320</th>
#       <td id="T_37e93_row1_col0" class="data row1 col0" >Volvo XC60 D3 Kinetic</td>
#       <td id="T_37e93_row1_col1" class="data row1 col1" >Automatic</td>
#       <td id="T_37e93_row1_col2" class="data row1 col2" >2012</td>
#       <td id="T_37e93_row1_col3" class="data row1 col3" >115992</td>
#       <td id="T_37e93_row1_col4" class="data row1 col4" >Diesel</td>
#       <td id="T_37e93_row1_col5" class="data row1 col5" >Dealer</td>
#       <td id="T_37e93_row1_col6" class="data row1 col6" >1750000</td>
#     </tr>
#     <tr>
#       <th id="T_37e93_level0_row2" class="row_heading level0 row2" >44</th>
#       <td id="T_37e93_row2_col0" class="data row2 col0" >Audi Q7 35 TDI Quattro Premium</td>
#       <td id="T_37e93_row2_col1" class="data row2 col1" >Automatic</td>
#       <td id="T_37e93_row2_col2" class="data row2 col2" >2009</td>
#       <td id="T_37e93_row2_col3" class="data row2 col3" >78000</td>
#       <td id="T_37e93_row2_col4" class="data row2 col4" >Diesel</td>
#       <td id="T_37e93_row2_col5" class="data row2 col5" >Dealer</td>
#       <td id="T_37e93_row2_col6" class="data row2 col6" >1250000</td>
#     </tr>
#     <tr>
#       <th id="T_37e93_level0_row3" class="row_heading level0 row3" >4049</th>
#       <td id="T_37e93_row3_col0" class="data row3 col0" >Hyundai Creta 1.6 CRDi SX Plus</td>
#       <td id="T_37e93_row3_col1" class="data row3 col1" >Manual</td>
#       <td id="T_37e93_row3_col2" class="data row3 col2" >2016</td>
#       <td id="T_37e93_row3_col3" class="data row3 col3" >60000</td>
#       <td id="T_37e93_row3_col4" class="data row3 col4" >Diesel</td>
#       <td id="T_37e93_row3_col5" class="data row3 col5" >Individual</td>
#       <td id="T_37e93_row3_col6" class="data row3 col6" >1249000</td>
#     </tr>
#     <tr>
#       <th id="T_37e93_level0_row4" class="row_heading level0 row4" >1057</th>
#       <td id="T_37e93_row4_col0" class="data row4 col0" >Skoda Octavia Elegance 2.0 TDI AT</td>
#       <td id="T_37e93_row4_col1" class="data row4 col1" >Automatic</td>
#       <td id="T_37e93_row4_col2" class="data row4 col2" >2014</td>
#       <td id="T_37e93_row4_col3" class="data row4 col3" >135000</td>
#       <td id="T_37e93_row4_col4" class="data row4 col4" >Diesel</td>
#       <td id="T_37e93_row4_col5" class="data row4 col5" >Individual</td>
#       <td id="T_37e93_row4_col6" class="data row4 col6" >1200000</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_7a23a_row0_col2 {
#   background-color: #ff9966;
#   color: #000000;
# }
# #T_7a23a_row0_col3 {
#   background-color: #ff7887;
#   color: #f1f1f1;
# }
# #T_7a23a_row0_col6, #T_7a23a_row1_col2, #T_7a23a_row2_col2, #T_7a23a_row3_col3 {
#   background-color: #ffff00;
#   color: #000000;
# }
# #T_7a23a_row1_col3, #T_7a23a_row3_col2, #T_7a23a_row4_col2, #T_7a23a_row4_col3, #T_7a23a_row4_col6 {
#   background-color: #ff00ff;
#   color: #f1f1f1;
# }
# #T_7a23a_row1_col6 {
#   background-color: #ffaa55;
#   color: #000000;
# }
# #T_7a23a_row2_col3 {
#   background-color: #ff16e9;
#   color: #f1f1f1;
# }
# #T_7a23a_row2_col6 {
#   background-color: #ff44bb;
#   color: #f1f1f1;
# }
# #T_7a23a_row3_col6 {
#   background-color: #ff22dd;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_7a23a_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >transmission</th>
#       <th class="col_heading level0 col2" >year</th>
#       <th class="col_heading level0 col3" >km_driven</th>
#       <th class="col_heading level0 col4" >fuel</th>
#       <th class="col_heading level0 col5" >seller_type</th>
#       <th class="col_heading level0 col6" >selling_price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7a23a_level0_row0" class="row_heading level0 row0" >236</th>
#       <td id="T_7a23a_row0_col0" class="data row0 col0" >Toyota Innova 2.5 G (Diesel) 7 Seater BS IV</td>
#       <td id="T_7a23a_row0_col1" class="data row0 col1" >Manual</td>
#       <td id="T_7a23a_row0_col2" class="data row0 col2" >2010</td>
#       <td id="T_7a23a_row0_col3" class="data row0 col3" >163000</td>
#       <td id="T_7a23a_row0_col4" class="data row0 col4" >Diesel</td>
#       <td id="T_7a23a_row0_col5" class="data row0 col5" >Individual</td>
#       <td id="T_7a23a_row0_col6" class="data row0 col6" >700000</td>
#     </tr>
#     <tr>
#       <th id="T_7a23a_level0_row1" class="row_heading level0 row1" >957</th>
#       <td id="T_7a23a_row1_col0" class="data row1 col0" >Mahindra Scorpio M2DI</td>
#       <td id="T_7a23a_row1_col1" class="data row1 col1" >Manual</td>
#       <td id="T_7a23a_row1_col2" class="data row1 col2" >2012</td>
#       <td id="T_7a23a_row1_col3" class="data row1 col3" >110000</td>
#       <td id="T_7a23a_row1_col4" class="data row1 col4" >Diesel</td>
#       <td id="T_7a23a_row1_col5" class="data row1 col5" >Individual</td>
#       <td id="T_7a23a_row1_col6" class="data row1 col6" >600000</td>
#     </tr>
#     <tr>
#       <th id="T_7a23a_level0_row2" class="row_heading level0 row2" >818</th>
#       <td id="T_7a23a_row2_col0" class="data row2 col0" >Maruti Ertiga ZDI</td>
#       <td id="T_7a23a_row2_col1" class="data row2 col1" >Manual</td>
#       <td id="T_7a23a_row2_col2" class="data row2 col2" >2012</td>
#       <td id="T_7a23a_row2_col3" class="data row2 col3" >120000</td>
#       <td id="T_7a23a_row2_col4" class="data row2 col4" >Diesel</td>
#       <td id="T_7a23a_row2_col5" class="data row2 col5" >Individual</td>
#       <td id="T_7a23a_row2_col6" class="data row2 col6" >480000</td>
#     </tr>
#     <tr>
#       <th id="T_7a23a_level0_row3" class="row_heading level0 row3" >2955</th>
#       <td id="T_7a23a_row3_col0" class="data row3 col0" >Toyota Innova 2.5 G4 Diesel 7-seater</td>
#       <td id="T_7a23a_row3_col1" class="data row3 col1" >Manual</td>
#       <td id="T_7a23a_row3_col2" class="data row3 col2" >2007</td>
#       <td id="T_7a23a_row3_col3" class="data row3 col3" >223000</td>
#       <td id="T_7a23a_row3_col4" class="data row3 col4" >Diesel</td>
#       <td id="T_7a23a_row3_col5" class="data row3 col5" >Individual</td>
#       <td id="T_7a23a_row3_col6" class="data row3 col6" >440000</td>
#     </tr>
#     <tr>
#       <th id="T_7a23a_level0_row4" class="row_heading level0 row4" >986</th>
#       <td id="T_7a23a_row4_col0" class="data row4 col0" >Ford Endeavour Hurricane Limited Edition</td>
#       <td id="T_7a23a_row4_col1" class="data row4 col1" >Automatic</td>
#       <td id="T_7a23a_row4_col2" class="data row4 col2" >2007</td>
#       <td id="T_7a23a_row4_col3" class="data row4 col3" >110000</td>
#       <td id="T_7a23a_row4_col4" class="data row4 col4" >Diesel</td>
#       <td id="T_7a23a_row4_col5" class="data row4 col5" >Individual</td>
#       <td id="T_7a23a_row4_col6" class="data row4 col6" >400000</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_d604a_row0_col2 {
#   background-color: #ff807f;
#   color: #f1f1f1;
# }
# #T_d604a_row0_col3 {
#   background-color: #ff5da2;
#   color: #f1f1f1;
# }
# #T_d604a_row0_col6, #T_d604a_row1_col2, #T_d604a_row2_col2, #T_d604a_row3_col3, #T_d604a_row4_col2 {
#   background-color: #ffff00;
#   color: #000000;
# }
# #T_d604a_row1_col3, #T_d604a_row2_col3, #T_d604a_row3_col2, #T_d604a_row4_col3, #T_d604a_row4_col6 {
#   background-color: #ff00ff;
#   color: #f1f1f1;
# }
# #T_d604a_row1_col6 {
#   background-color: #ffee11;
#   color: #000000;
# }
# #T_d604a_row2_col6 {
#   background-color: #ffea15;
#   color: #000000;
# }
# #T_d604a_row3_col6 {
#   background-color: #ff32cd;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_d604a_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >transmission</th>
#       <th class="col_heading level0 col2" >year</th>
#       <th class="col_heading level0 col3" >km_driven</th>
#       <th class="col_heading level0 col4" >fuel</th>
#       <th class="col_heading level0 col5" >seller_type</th>
#       <th class="col_heading level0 col6" >selling_price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d604a_level0_row0" class="row_heading level0 row0" >2359</th>
#       <td id="T_d604a_row0_col0" class="data row0 col0" >Volkswagen Vento 1.5 TDI Highline BSIV</td>
#       <td id="T_d604a_row0_col1" class="data row0 col1" >Manual</td>
#       <td id="T_d604a_row0_col2" class="data row0 col2" >2019</td>
#       <td id="T_d604a_row0_col3" class="data row0 col3" >5400</td>
#       <td id="T_d604a_row0_col4" class="data row0 col4" >Diesel</td>
#       <td id="T_d604a_row0_col5" class="data row0 col5" >Dealer</td>
#       <td id="T_d604a_row0_col6" class="data row0 col6" >1350000</td>
#     </tr>
#     <tr>
#       <th id="T_d604a_level0_row1" class="row_heading level0 row1" >1778</th>
#       <td id="T_d604a_row1_col0" class="data row1 col0" >Ford EcoSport 1.5 TDCi Titanium Plus BSIV</td>
#       <td id="T_d604a_row1_col1" class="data row1 col1" >Manual</td>
#       <td id="T_d604a_row1_col2" class="data row1 col2" >2020</td>
#       <td id="T_d604a_row1_col3" class="data row1 col3" >1010</td>
#       <td id="T_d604a_row1_col4" class="data row1 col4" >Diesel</td>
#       <td id="T_d604a_row1_col5" class="data row1 col5" >Dealer</td>
#       <td id="T_d604a_row1_col6" class="data row1 col6" >1334000</td>
#     </tr>
#     <tr>
#       <th id="T_d604a_level0_row2" class="row_heading level0 row2" >1780</th>
#       <td id="T_d604a_row2_col0" class="data row2 col0" >Ford Ecosport Thunder Edition Diesel</td>
#       <td id="T_d604a_row2_col1" class="data row2 col1" >Manual</td>
#       <td id="T_d604a_row2_col2" class="data row2 col2" >2020</td>
#       <td id="T_d604a_row2_col3" class="data row2 col3" >1010</td>
#       <td id="T_d604a_row2_col4" class="data row2 col4" >Diesel</td>
#       <td id="T_d604a_row2_col5" class="data row2 col5" >Dealer</td>
#       <td id="T_d604a_row2_col6" class="data row2 col6" >1331000</td>
#     </tr>
#     <tr>
#       <th id="T_d604a_level0_row3" class="row_heading level0 row3" >3615</th>
#       <td id="T_d604a_row3_col0" class="data row3 col0" >Honda City i-VTEC CVT ZX</td>
#       <td id="T_d604a_row3_col1" class="data row3 col1" >Automatic</td>
#       <td id="T_d604a_row3_col2" class="data row3 col2" >2018</td>
#       <td id="T_d604a_row3_col3" class="data row3 col3" >13000</td>
#       <td id="T_d604a_row3_col4" class="data row3 col4" >Petrol</td>
#       <td id="T_d604a_row3_col5" class="data row3 col5" >Dealer</td>
#       <td id="T_d604a_row3_col6" class="data row3 col6" >1165000</td>
#     </tr>
#     <tr>
#       <th id="T_d604a_level0_row4" class="row_heading level0 row4" >1775</th>
#       <td id="T_d604a_row4_col0" class="data row4 col0" >Ford EcoSport 1.5 Ti VCT MT Titanium BE BSIV</td>
#       <td id="T_d604a_row4_col1" class="data row4 col1" >Manual</td>
#       <td id="T_d604a_row4_col2" class="data row4 col2" >2020</td>
#       <td id="T_d604a_row4_col3" class="data row4 col3" >1010</td>
#       <td id="T_d604a_row4_col4" class="data row4 col4" >Petrol</td>
#       <td id="T_d604a_row4_col5" class="data row4 col5" >Dealer</td>
#       <td id="T_d604a_row4_col6" class="data row4 col6" >1119000</td>
#     </tr>
#   </tbody>
# </table>
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'seller_type : km_driven comparsion')

# %% [markdown]
# Recommending Vehicles Based on Fuel

# %%
def recommend_vehicle(x):
    y = Data[["fuel",'name',"km_driven","transmission","selling_price"]][Data["fuel"] == x]
    y = y.sort_values(by="selling_price",ascending=False)
    return y.head(15)

# %% [markdown]
# Diesel

# %%
recommend_vehicle("Diesel")
# Out:
#         fuel                                               name  km_driven  \
# 89    Diesel  Mercedes-Benz S-Class S 350d Connoisseurs Edition       6500
# 3969  Diesel            Mercedes-Benz GLS 2016-2020 350d 4MATIC      77350
# 919   Diesel                            BMW X5 xDrive 30d xLine      30000
# 612   Diesel                            BMW X5 xDrive 30d xLine      30000
# 593   Diesel                            BMW X5 xDrive 30d xLine      30000
# 2239  Diesel                            BMW X5 xDrive 30d xLine      30000
# 2258  Diesel                            BMW X5 xDrive 30d xLine      30000
# 1836  Diesel                            BMW X5 xDrive 30d xLine      30000
# 574   Diesel                            BMW X5 xDrive 30d xLine      30000
# 2739  Diesel                            BMW X5 xDrive 30d xLine      30000
# 1023  Diesel                            BMW X5 xDrive 30d xLine      30000
# 900   Diesel                            BMW X5 xDrive 30d xLine      30000
# 555   Diesel                            BMW X5 xDrive 30d xLine      30000
# 3883  Diesel                      BMW 5 Series 520d Luxury Line      12999
# 3453  Diesel                      BMW 5 Series 520d Luxury Line       9422
#
#      transmission  selling_price
# 89      Automatic        8150000
# 3969    Automatic        5500000
# 919     Automatic        4950000
# 612     Automatic        4950000
# 593     Automatic        4950000
# 2239    Automatic        4950000
# 2258    Automatic        4950000
# 1836    Automatic        4950000
# 574     Automatic        4950000
# 2739    Automatic        4950000
# 1023    Automatic        4950000
# 900     Automatic        4950000
# 555     Automatic        4950000
# 3883    Automatic        4800000
# 3453    Automatic        4800000

# %% [markdown]
# Petrol

# %%
recommend_vehicle("Petrol")
# Out:
#         fuel                                        name  km_driven  \
# 3872  Petrol    Audi RS7 2015-2019 Sportback Performance      13000
# 2580  Petrol  Mercedes-Benz E-Class Exclusive E 200 BSIV       9800
# 101   Petrol  Mercedes-Benz E-Class Exclusive E 200 BSIV       9800
# 988   Petrol              Land Rover Discovery S 2.0 SD4      68000
# 1065  Petrol                  Audi A4 30 TFSI Technology      22000
# 2323  Petrol                  Audi A4 30 TFSI Technology      22000
# 163   Petrol             Jaguar XJ 5.0 L V8 Supercharged      40000
# 4224  Petrol                  Toyota Fortuner 2.7 2WD AT      70000
# 2175  Petrol               Jaguar XF 5.0 Litre V8 Petrol      66363
# 536   Petrol               Jaguar XF 5.0 Litre V8 Petrol      66363
# 969   Petrol                     Toyota Camry 2.5 Hybrid      20000
# 2299  Petrol                     Toyota Camry Hybrid 2.5      20118
# 4311  Petrol                     Toyota Camry Hybrid 2.5      20118
# 3874  Petrol                          MG Hector Smart AT      18000
# 3854  Petrol       Audi Q5 2.0 TFSI Quattro Premium Plus      62237
#
#      transmission  selling_price
# 3872    Automatic        8900000
# 2580    Automatic        4500000
# 101     Automatic        4500000
# 988     Automatic        4000000
# 1065    Automatic        3100000
# 2323    Automatic        3100000
# 163     Automatic        2550000
# 4224    Automatic        2500000
# 2175    Automatic        2050000
# 536     Automatic        2050000
# 969     Automatic        1900000
# 2299    Automatic        1900000
# 4311    Automatic        1900000
# 3874    Automatic        1860000
# 3854    Automatic        1850000

# %% [markdown]
# CNG

# %%
recommend_vehicle("CNG")
# Out:
#      fuel                                    name  km_driven transmission  \
# 4076  CNG                   Maruti Ertiga VXI CNG      56600       Manual
# 3464  CNG                   Maruti Ertiga VXI CNG      80000       Manual
# 712   CNG                   Maruti Ertiga VXI CNG      56228       Manual
# 2785  CNG           Hyundai Santro Magna CNG BSIV      10000       Manual
# 3112  CNG        Maruti Eeco CNG 5 Seater AC BSIV       7000       Manual
# 3778  CNG        Maruti Eeco CNG 5 Seater AC BSIV       4000       Manual
# 3048  CNG        Maruti Eeco CNG 5 Seater AC BSIV      10000       Manual
# 4063  CNG  Maruti Eeco 5 STR With AC Plus HTR CNG      14100       Manual
# 4140  CNG  Maruti Eeco 5 STR With AC Plus HTR CNG      45000       Manual
# 22    CNG                Maruti Celerio Green VXI      78000       Manual
# 4001  CNG                Maruti Celerio Green VXI      78000       Manual
# 9     CNG                Maruti Celerio Green VXI      78000       Manual
# 2092  CNG                  Maruti Wagon R LXI CNG      30000       Manual
# 3482  CNG                  Maruti Wagon R LXI CNG      80000       Manual
# 3090  CNG                  Maruti Wagon R CNG LXI      59100       Manual
#
#       selling_price
# 4076         595000
# 3464         587000
# 712          525000
# 2785         520000
# 3112         495000
# 3778         470000
# 3048         470000
# 4063         440000
# 4140         409999
# 22           365000
# 4001         365000
# 9            365000
# 2092         350000
# 3482         325000
# 3090         310000

# %% [markdown]
# LPG

# %%
recommend_vehicle("LPG")
# Out:
#      fuel                               name  km_driven transmission  \
# 1435  LPG              Hyundai i10 Magna LPG      29000       Manual
# 1998  LPG              Hyundai i10 Magna LPG      90000       Manual
# 495   LPG  Hyundai Santro Xing GLS Audio LPG     100000       Manual
# 657   LPG              Hyundai i10 Magna LPG      88600       Manual
# 3752  LPG         Hyundai EON LPG Magna Plus     110000       Manual
# 2380  LPG             Maruti Wagon R Duo Lxi      50000       Manual
# 703   LPG    Hyundai Santro Xing GL Plus LPG      60000       Manual
# 1355  LPG        Maruti Wagon R LXI LPG BSIV      80000       Manual
# 157   LPG             Maruti Wagon R DUO LPG      90000       Manual
# 3341  LPG              Chevrolet Beat LT LPG     110000       Manual
# 483   LPG         Hyundai EON LPG Magna Plus      90000       Manual
# 1670  LPG       Maruti Wagon R LXI DUO BS IV      60000       Manual
# 3394  LPG         Hyundai EON LPG Magna Plus     170000       Manual
# 1810  LPG       Maruti Wagon R LXI DUO BSIII      60000       Manual
# 1942  LPG       Maruti Wagon R LXI DUO BSIII     152000       Manual
#
#       selling_price
# 1435         290000
# 1998         275000
# 495          250000
# 657          250000
# 3752         240000
# 2380         240000
# 703          229999
# 1355         220000
# 157          210000
# 3341         200000
# 483          180000
# 1670         180000
# 3394         170000
# 1810         155000
# 1942         125000

# %% [markdown]
# Electric

# %%
recommend_vehicle("Electric")
# Out:
#           fuel                 name  km_driven transmission  selling_price
# 4145  Electric  Toyota Camry Hybrid      62000    Automatic         310000

# %% [markdown]
# Recommending Vehicles Based on Owner

# %%
def recommend_vehicle(x):
    y = Data[["owner",'name',"km_driven","transmission","selling_price"]][Data["owner"] == x]
    y = y.sort_values(by="selling_price",ascending=False)
    return y.head(15)

# %% [markdown]
# First Owner

# %%
recommend_vehicle("First Owner")
# Out:
#             owner                                               name  \
# 3872  First Owner           Audi RS7 2015-2019 Sportback Performance
# 89    First Owner  Mercedes-Benz S-Class S 350d Connoisseurs Edition
# 3969  First Owner            Mercedes-Benz GLS 2016-2020 350d 4MATIC
# 919   First Owner                            BMW X5 xDrive 30d xLine
# 593   First Owner                            BMW X5 xDrive 30d xLine
# 1023  First Owner                            BMW X5 xDrive 30d xLine
# 2739  First Owner                            BMW X5 xDrive 30d xLine
# 1836  First Owner                            BMW X5 xDrive 30d xLine
# 612   First Owner                            BMW X5 xDrive 30d xLine
# 2258  First Owner                            BMW X5 xDrive 30d xLine
# 900   First Owner                            BMW X5 xDrive 30d xLine
# 2239  First Owner                            BMW X5 xDrive 30d xLine
# 555   First Owner                            BMW X5 xDrive 30d xLine
# 574   First Owner                            BMW X5 xDrive 30d xLine
# 3883  First Owner                      BMW 5 Series 520d Luxury Line
#
#       km_driven transmission  selling_price
# 3872      13000    Automatic        8900000
# 89         6500    Automatic        8150000
# 3969      77350    Automatic        5500000
# 919       30000    Automatic        4950000
# 593       30000    Automatic        4950000
# 1023      30000    Automatic        4950000
# 2739      30000    Automatic        4950000
# 1836      30000    Automatic        4950000
# 612       30000    Automatic        4950000
# 2258      30000    Automatic        4950000
# 900       30000    Automatic        4950000
# 2239      30000    Automatic        4950000
# 555       30000    Automatic        4950000
# 574       30000    Automatic        4950000
# 3883      12999    Automatic        4800000

# %% [markdown]
# Second Owner

# %%
recommend_vehicle("Second Owner")
# Out:
#              owner                                            name  km_driven  \
# 539   Second Owner  Mercedes-Benz GL-Class 350 CDI Blue Efficiency     100000
# 2178  Second Owner  Mercedes-Benz GL-Class 350 CDI Blue Efficiency     100000
# 163   Second Owner                 Jaguar XJ 5.0 L V8 Supercharged      40000
# 4224  Second Owner                      Toyota Fortuner 2.7 2WD AT      70000
# 836   Second Owner                Mercedes-Benz M-Class ML 350 CDI      79500
# 3596  Second Owner      Land Rover Range Rover Evoque 2.2L Dynamic     149000
# 536   Second Owner                   Jaguar XF 5.0 Litre V8 Petrol      66363
# 2175  Second Owner                   Jaguar XF 5.0 Litre V8 Petrol      66363
# 1417  Second Owner            Jaguar XF 3.0 Litre S Premium Luxury      64000
# 1532  Second Owner            Jaguar XF 3.0 Litre S Premium Luxury      50000
# 2190  Second Owner                  Toyota Innova Crysta 2.4 GX AT      23974
# 550   Second Owner                  Toyota Innova Crysta 2.4 GX AT      23974
# 2499  Second Owner                              BMW 7 Series 730Ld     100000
# 43    Second Owner                    BMW 3 Series 320d Sport Line      75800
# 94    Second Owner                    Audi A6 2.0 TDI Premium Plus      34000
#
#      transmission  selling_price
# 539     Automatic        4400000
# 2178    Automatic        4400000
# 163     Automatic        2550000
# 4224    Automatic        2500000
# 836     Automatic        2500000
# 3596    Automatic        2349000
# 536     Automatic        2050000
# 2175    Automatic        2050000
# 1417    Automatic        2000000
# 1532    Automatic        1800000
# 2190    Automatic        1725000
# 550     Automatic        1725000
# 2499    Automatic        1700000
# 43      Automatic        1550000
# 94      Automatic        1470000

# %% [markdown]
# Third Owner

# %%
recommend_vehicle("Third Owner")
# Out:
#             owner                                       name  km_driven  \
# 1410  Third Owner                     Audi A4 35 TDI Premium      35000
# 3320  Third Owner                      Volvo XC60 D3 Kinetic     115992
# 44    Third Owner             Audi Q7 35 TDI Quattro Premium      78000
# 4049  Third Owner             Hyundai Creta 1.6 CRDi SX Plus      60000
# 1057  Third Owner          Skoda Octavia Elegance 2.0 TDI AT     135000
# 1362  Third Owner     Toyota Innova 2.5 VX (Diesel) 7 Seater      70000
# 3458  Third Owner                           Audi A4 1.8 TFSI      60000
# 2216  Third Owner          Skoda Octavia Elegance 2.0 TDI AT     135000
# 2315  Third Owner          Skoda Octavia Elegance 2.0 TDI AT     135000
# 2910  Third Owner                    BMW 5 Series 525d Sedan      45000
# 1560  Third Owner  Toyota Innova 2.5 Z Diesel 7 Seater BS IV      90000
# 1829  Third Owner     Toyota Innova 2.5 VX (Diesel) 7 Seater      80000
# 2796  Third Owner  Toyota Innova 2.5 Z Diesel 7 Seater BS IV     173000
# 692   Third Owner                     Mahindra XUV500 W6 2WD      90000
# 1999  Third Owner      Toyota Innova 2.5 G (Diesel) 7 Seater     186000
#
#      transmission  selling_price
# 1410    Automatic        2300000
# 3320    Automatic        1750000
# 44      Automatic        1250000
# 4049       Manual        1249000
# 1057    Automatic        1200000
# 1362       Manual        1200000
# 3458    Automatic        1200000
# 2216    Automatic        1200000
# 2315    Automatic        1200000
# 2910    Automatic        1200000
# 1560       Manual        1050000
# 1829       Manual         950000
# 2796       Manual         894999
# 692        Manual         825000
# 1999       Manual         800000

# %% [markdown]
# Fourth & Above Owner

# %%
recommend_vehicle("Fourth & Above Owner")
# Out:
#                      owner                                         name  \
# 236   Fourth & Above Owner  Toyota Innova 2.5 G (Diesel) 7 Seater BS IV
# 957   Fourth & Above Owner                        Mahindra Scorpio M2DI
# 818   Fourth & Above Owner                            Maruti Ertiga ZDI
# 2955  Fourth & Above Owner         Toyota Innova 2.5 G4 Diesel 7-seater
# 986   Fourth & Above Owner     Ford Endeavour Hurricane Limited Edition
# 1215  Fourth & Above Owner                Mahindra Bolero SLX 2WD BSIII
# 3982  Fourth & Above Owner                           Chevrolet Cruze LT
# 1608  Fourth & Above Owner         Volkswagen Vento New Diesel Highline
# 1633  Fourth & Above Owner                        Maruti Swift VDI BSIV
# 1040  Fourth & Above Owner                              Honda City VTEC
# 3041  Fourth & Above Owner                           Mahindra Quanto C4
# 2060  Fourth & Above Owner           Tata New Safari Dicor EX 4X2 BS IV
# 2823  Fourth & Above Owner                       Hyundai Sonata 2.4L AT
# 3387  Fourth & Above Owner                       Hyundai i20 1.2 Sportz
# 1830  Fourth & Above Owner                       Maruti Swift Vdi BSIII
#
#       km_driven transmission  selling_price
# 236      163000       Manual         700000
# 957      110000       Manual         600000
# 818      120000       Manual         480000
# 2955     223000       Manual         440000
# 986      110000    Automatic         400000
# 1215     150000       Manual         390000
# 3982      90000       Manual         380000
# 1608      86000       Manual         330000
# 1633     110000       Manual         320000
# 1040      90000       Manual         310000
# 3041     150000       Manual         290000
# 2060     110000       Manual         280000
# 2823      80000    Automatic         275000
# 3387      97700       Manual         260000
# 1830     200000       Manual         250000

# %% [markdown]
# Test Drive Car

# %%
recommend_vehicle("Test Drive Car")
# Out:
#                owner                                          name  km_driven  \
# 2359  Test Drive Car        Volkswagen Vento 1.5 TDI Highline BSIV       5400
# 1778  Test Drive Car     Ford EcoSport 1.5 TDCi Titanium Plus BSIV       1010
# 1780  Test Drive Car          Ford Ecosport Thunder Edition Diesel       1010
# 3615  Test Drive Car                      Honda City i-VTEC CVT ZX      13000
# 1775  Test Drive Car  Ford EcoSport 1.5 Ti VCT MT Titanium BE BSIV       1010
# 1795  Test Drive Car        Ford Ecosport 1.5 Petrol Titanium Plus       5166
# 1777  Test Drive Car                Ford Ecosport 1.5 Petrol Trend       1010
# 1716  Test Drive Car             Ford Ecosport 1.5 Diesel Titanium        101
# 2362  Test Drive Car         Ford Figo Aspire Titanium Plus Diesel      13000
# 1781  Test Drive Car                  Ford Freestyle Titanium Plus       1010
# 1774  Test Drive Car                     Ford Aspire Titanium BSIV       1010
# 1779  Test Drive Car                       Ford Freestyle Titanium       1010
# 1714  Test Drive Car                Ford Freestyle Titanium Diesel        101
# 1776  Test Drive Car                            Ford Figo Titanium       1111
# 2782  Test Drive Car                      Honda Jazz 1.5 VX i DTEC      24585
#
#      transmission  selling_price
# 2359       Manual        1350000
# 1778       Manual        1334000
# 1780       Manual        1331000
# 3615    Automatic        1165000
# 1775       Manual        1119000
# 1795       Manual        1100000
# 1777       Manual        1030000
# 1716       Manual        1000000
# 2362       Manual         894999
# 1781       Manual         852000
# 1774       Manual         828999
# 1779       Manual         811999
# 1714       Manual         784000
# 1776       Manual         746000
# 2782       Manual         700000

# %% [markdown]
# Recommending Vehicles Based on Seller Type

# %%
def recommend_vehicle(x):
    y = Data[["seller_type",'name',"km_driven","transmission","selling_price"]][Data["seller_type"] == x]
    y = y.sort_values(by="selling_price",ascending=False)
    return y.head(15)

# %% [markdown]
# INDIVIDUAL

# %%
recommend_vehicle("Individual")
# Out:
#      seller_type                                            name  km_driven  \
# 3453  Individual                   BMW 5 Series 520d Luxury Line       9422
# 963   Individual                               Audi A5 Sportback       1500
# 4047  Individual                 Volvo XC 90 D5 Inscription BSIV      80000
# 539   Individual  Mercedes-Benz GL-Class 350 CDI Blue Efficiency     100000
# 2178  Individual  Mercedes-Benz GL-Class 350 CDI Blue Efficiency     100000
# 968   Individual                    BMW 7 Series Signature 730Ld      47000
# 731   Individual           Land Rover Discovery Sport TD4 HSE 7S      68000
# 988   Individual                  Land Rover Discovery S 2.0 SD4      68000
# 1705  Individual                                 Audi Q5 2.0 TDI      35000
# 2503  Individual              Ford Endeavour 3.2 Titanium AT 4X4      20000
# 1290  Individual                 Toyota Fortuner 2.8 2WD AT BSIV      57000
# 2323  Individual                      Audi A4 30 TFSI Technology      22000
# 1065  Individual                      Audi A4 30 TFSI Technology      22000
# 3863  Individual                 Toyota Fortuner 2.8 4WD AT BSIV       5000
# 1026  Individual                     BMW 3 Series GT Luxury Line      30000
#
#      transmission  selling_price
# 3453    Automatic        4800000
# 963     Automatic        4700000
# 4047    Automatic        4500000
# 539     Automatic        4400000
# 2178    Automatic        4400000
# 968     Automatic        4000000
# 731     Automatic        4000000
# 988     Automatic        4000000
# 1705    Automatic        3500000
# 2503    Automatic        3200000
# 1290    Automatic        3200000
# 2323    Automatic        3100000
# 1065    Automatic        3100000
# 3863    Automatic        3100000
# 1026    Automatic        3050000

# %% [markdown]
# Dealer

# %%
recommend_vehicle("Dealer")
# Out:
#      seller_type                                               name  \
# 3872      Dealer           Audi RS7 2015-2019 Sportback Performance
# 89        Dealer  Mercedes-Benz S-Class S 350d Connoisseurs Edition
# 3969      Dealer            Mercedes-Benz GLS 2016-2020 350d 4MATIC
# 2258      Dealer                            BMW X5 xDrive 30d xLine
# 555       Dealer                            BMW X5 xDrive 30d xLine
# 919       Dealer                            BMW X5 xDrive 30d xLine
# 1023      Dealer                            BMW X5 xDrive 30d xLine
# 612       Dealer                            BMW X5 xDrive 30d xLine
# 1836      Dealer                            BMW X5 xDrive 30d xLine
# 593       Dealer                            BMW X5 xDrive 30d xLine
# 2239      Dealer                            BMW X5 xDrive 30d xLine
# 2739      Dealer                            BMW X5 xDrive 30d xLine
# 574       Dealer                            BMW X5 xDrive 30d xLine
# 900       Dealer                            BMW X5 xDrive 30d xLine
# 3883      Dealer                      BMW 5 Series 520d Luxury Line
#
#       km_driven transmission  selling_price
# 3872      13000    Automatic        8900000
# 89         6500    Automatic        8150000
# 3969      77350    Automatic        5500000
# 2258      30000    Automatic        4950000
# 555       30000    Automatic        4950000
# 919       30000    Automatic        4950000
# 1023      30000    Automatic        4950000
# 612       30000    Automatic        4950000
# 1836      30000    Automatic        4950000
# 593       30000    Automatic        4950000
# 2239      30000    Automatic        4950000
# 2739      30000    Automatic        4950000
# 574       30000    Automatic        4950000
# 900       30000    Automatic        4950000
# 3883      12999    Automatic        4800000

# %% [markdown]
# Trust Mark Dealer

# %%
recommend_vehicle("Trustmark Dealer")
# Out:
#            seller_type                                   name  km_driven  \
# 927   Trustmark Dealer                 Toyota Fortuner 4x2 AT      47162
# 563   Trustmark Dealer                 Toyota Fortuner 4x2 AT      47162
# 1031  Trustmark Dealer                 Toyota Fortuner 4x2 AT      47162
# 908   Trustmark Dealer                 Toyota Fortuner 4x2 AT      47162
# 2747  Trustmark Dealer                 Toyota Fortuner 4x2 AT      47162
# 620   Trustmark Dealer                 Toyota Fortuner 4x2 AT      47162
# 601   Trustmark Dealer                 Toyota Fortuner 4x2 AT      47162
# 582   Trustmark Dealer                 Toyota Fortuner 4x2 AT      47162
# 2266  Trustmark Dealer                 Toyota Fortuner 4x2 AT      47162
# 1844  Trustmark Dealer                 Toyota Fortuner 4x2 AT      47162
# 2247  Trustmark Dealer                 Toyota Fortuner 4x2 AT      47162
# 1623  Trustmark Dealer                 Toyota Fortuner 4x2 AT      79641
# 4096  Trustmark Dealer         Mahindra XUV500 W10 1.99 mHawk      23670
# 1626  Trustmark Dealer             Toyota Corolla Altis GL MT      64156
# 2187  Trustmark Dealer  Hyundai Creta 1.6 SX Automatic Diesel      54634
#
#      transmission  selling_price
# 927     Automatic        2600000
# 563     Automatic        2600000
# 1031    Automatic        2600000
# 908     Automatic        2600000
# 2747    Automatic        2600000
# 620     Automatic        2600000
# 601     Automatic        2600000
# 582     Automatic        2600000
# 2266    Automatic        2600000
# 1844    Automatic        2600000
# 2247    Automatic        2600000
# 1623    Automatic        2595000
# 4096       Manual        1250000
# 1626       Manual        1150000
# 2187    Automatic        1150000
